# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas2003a/Colab_repos/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

datos = pd.read_csv("creditos.csv", sep = ";")
# Out:
#      edad  credito  cumplio
# 0      18   363112        0
# 1      19   477965        1
# 2      20   239072        0
# 3      22   195265        0
# 4      22   482174        0
# ..    ...      ...      ...
# 195    55   100000        0
# 196    55   523144        0
# 197    55   543771        0
# 198    56   285288        0
# 199    57   422969        0
#
# [200 rows x 3 columns]

# %%
import matplotlib.pyplot as mat

mat.ylabel("EtiquetaY")
mat.xlabel("EtiquetaX")

mat.scatter(datos["credito"], datos["cumplio"], color = "green")
mat.show()

# %%
from sklearn import linear_model

regresion = linear_model.LinearRegression()

credito = datos["credito"].values.reshape((-1,1))

modelo = regresion.fit(credito,datos["cumplio"])

# %%
entrada = [[0],[1]]

prediccion = modelo.predict(entrada)

mat.scatter(entrada,prediccion, color = "blue")
mat.plot(entrada,prediccion, color="black")

mat.xlabel("credito")
mat.ylabel("cumplió")

mat.scatter(datos["credito"], datos["cumplio"], color= "green")
mat.show()
